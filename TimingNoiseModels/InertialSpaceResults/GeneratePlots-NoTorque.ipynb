# %%
from matplotlib import pyplot as plt
import nsmod
import os 
import numpy as np
from numpy import sin, cos, tan
from matplotlib.ticker import MultipleLocator 
# %matplotlib inline

from nsmod.switching_torque_with_Euler import main
from nsmod import Plot, File_Functions, Model
# Out:
# /usr/lib/python2.7/dist-packages/gtk-2.0/gtk/__init__.py:127: RuntimeWarning: PyOS_InputHook is not available for interactive use of PyGTK
#   set_interactive(1)

# %% [markdown]
# # Generating plots for the Inertial space results
# In this notebook all plots for this section are generated. We will use the `nsmod.switching_torque_with_Euler` model with the switching paramater $\upsilon=0$. This reduces the number of models that we need while the speed savings are most likely negligible.

# %% [markdown]
# ## Biaxial body with no torque

# %%
T = 5e3
omega0 = 10
epsI3 = 1e-3
a0 = 15.0
file_name = main(chi0=80, epsI3=epsI3, epsA=0.0, omega0=omega0, T=T, 
                 n=10000, error=1e-18, a0=a0, cleanup=False)

axes = Plot.Spherical_Plot(file_name, save_fig=True)
plt.show()

axes = Plot.Euler_Angles(file_name, save_fig=True, analytic=True)

plt.show()
# Out:
# Saving figure as ./img/Spherical_Plot_chi0_80.00000_omega0_1.00e+01_epsI3_1.00e-03_n_10000_a0_15.00000_T_5.00e+03_upsilon_0.000_epsA_0.00e+00_epsI1_0.00e+00_AnomTorque_1.pdf
# Saving figure as ./img/Euler_Angles_chi0_80.00000_omega0_1.00e+01_epsI3_1.00e-03_n_10000_a0_15.00000_T_5.00e+03_upsilon_0.000_epsA_0.00e+00_epsI1_0.00e+00_AnomTorque_1.pdf

# %% [markdown]
# ## Variation with chi

# %%
a0 = 20
epsI3 = 1e-3
omega0 = 1 * 2 * np.pi
epsA = 0.0
T = 5e3

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, 20.0, 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$"]
color_list = ["b", "r", "g"]
#chi_list = [np.degrees(theta_0)]
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

for i, chi0 in enumerate(chi0_list):
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                     n=1000, error=1e-14, a0=a0, cleanup=True, )
    
    time, w1, w2, w3, theta, phi, psi = nsmod.File_Functions.Euler_Angles_Import(file_name)
    (t_scaled, scale_val) = nsmod.Useful_Tools.Sort_Out_Some_Axis(time)

    ax1 = nsmod.Plot.big_phi_dot(file_name, ax=ax1, label=label_list[i], color=color_list[i])

    ax2 = nsmod.Plot.big_theta(file_name, ax=ax2, label=label_list[i], color=color_list[i])
    
# Add horizontal lines to ax1; note phi dot is the same regardless of chi
xfit, yfit, f_p = nsmod.Useful_Tools.Fit_Function(time, phi, 1)
phi_dot = f_p[0]
ax1.axhline(phi_dot, ls="--", color="k",) #label=r"$\dot{\phi}$")
ax1.text(0.95*ax1.get_xlim()[1], 1.0001*(phi_dot), r"$\dot{\phi}$", size=22)
xfit, yfit, f_p = nsmod.Useful_Tools.Fit_Function(time, psi, 1)
psi_dot = f_p[0]
#ax1.axhline(phi_dot+psi_dot, ls="-.", color="k", )#label=r"$\dot{\phi}+ \dot{\psi}$")
#ax1.text(0.9*ax1.get_xlim()[1], 0.9998*(phi_dot+psi_dot), r"$\dot{\phi}+ \dot{\psi}$", size=22)

delta = 0.015
ax1.set_ylim(6.285-delta, 6.285+delta)
ax1.legend(framealpha=0.7, loc=2, ncol=1)
fig1.savefig("img/frequency_variation_with_chi.pdf")

# Add horizontal lines tp ax2; note psi dot is the same regardless of chi
ax2.set_yticks([10.0, 20.0,30,40, 60.0,80.0, 100])
ax2.set_yticklabels([r"$\theta/2$", r"$\theta$", r"$3\theta/2$", r"$2\theta$", r"$3\theta$", r"$4\theta$", r"$5\theta$"])
ax2.grid(True, axis='y')
ax2.legend(framealpha=0.9, loc=1)
fig2.savefig("img/polar_angle_variation_with_chi.pdf")

plt.show()

# %% [markdown]
# ## Lets plot m

# %%
from numpy import sin, cos
from mpl_toolkits.mplot3d import Axes3D
import pylab as py

def Plot_m(file_name):
    (time, w1, w2, w3, theta, phi, psi) = nsmod.File_Functions.Euler_Angles_Import(file_name)
    #(t_scaled, scale_val) = nsmod.Useful_Tools.Sort_Out_Some_Axis(time)
    
    
    PD = nsmod.File_Functions.Parameter_Dictionary(file_name)
    #epsI1 = float(PD['epsI1'])
    chi = np.radians(float(PD['chi']))
  
    def m(theta, phi, psi, chi):
        mx = cos(phi) * cos(psi) * sin(chi) - sin(phi) * cos(theta) * sin(psi) * sin(chi) + sin(phi) * sin(theta) * cos(chi)
        my = sin(phi) * cos(psi) * sin(chi) + cos(phi) * cos(theta) * sin(psi) * sin(chi) - cos(phi) * sin(theta) * cos(chi)
        mz = sin(theta) * sin(psi) * sin(chi) + cos(theta) * cos(chi)
        return np.array([mx, my, mz])
    
    def n(theta, phi, psi):
        nx = sin(psi) * sin(theta)
        ny = cos(psi) * sin(theta)
        nz =cos(theta) 
        return np.array([nx, ny, nz])
    
    m_array = m(theta, phi, psi, chi)
    
    n_array = n(theta, phi, psi)
    
    
    ax = py.subplot(111, projection="3d")
    ax.plot(m_array[0], m_array[1], m_array[2])
    ax.plot(n_array[0], n_array[1], n_array[2])
    ax.set_zlabel("Z")
    #ax.set_xlim(-1, 1)
    #ax.set_ylim(-1, 1)
    #ax.set_zlim(0, 1)
    py.show()

    #py.plot(time, phi)
    #py.show() 

    #py.plot(m_array[0])
    #py.plot(m_array[1])
    #py.plot(m_array[2])
    #py.show()

# %%
a_int=30
epsI3 = 1e-1
chi = 89
omega0 = 1e2
t1 =  4.1 * np.pi / (omega0 * epsI3)
#t1 =  1 * 2 * np.pi / (omega0)
a_int_d = np.radians(a_int)
theta_0 = np.arccos(cos(a_int_d) * (1 + epsI3) * pow(pow(sin(a_int_d), 2) 
                            + pow(cos(a_int_d) * (1 + epsI3), 2), -0.5))
#chi = np.degrees(theta_0)

file_name = Model.Run_with_Euler(chi=chi, epsI1=0.0, epsI3=epsI3, epsA=0.0, omega0=omega0, t1=t1, n=10000, a_int=a_int)
Plot_m(file_name)
# Out:
# overwrite=False, therefore I will not delete this file

# %% [markdown]
# ## Timing residuals and slowdown

# %%
a0 = 20
epsI3 = 1e-3
omega0 = 2 * np.pi

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, np.degrees(theta_0), 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$", "something else"]
color_list = ["b", "r", "g", "k"]

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

        

for chi0, label, color in zip(chi0_list, label_list, color_list):
    
    #file_name = nsmod.Model.Run_with_Euler(chi=chi, epsI3=epsI3, epsA=0.0, 
    #                                       omega0=omega0, t1=5e3, n=10000, 
    #                                       error=1e-16, a_int=a_int,
    #                                       overwrite=False)
    
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=0.0, omega0=omega0, T=5e3, 
                     n=1000, error=1e-16, a0=a0, cleanup=True)
    
    ax1 = Plot.timing_residual(file_name, ax=ax1, order=2,
                                    label=label, color=color)
    
    ax2 = Plot.nu_dot(file_name, ax=ax2, normalise=True,
                                    label=label, color=color)
    
ax1.axhline(0.0, ls="-", color="k", lw=.5)    
ax1.legend(framealpha=0.9, loc=1)
fig1.savefig("img/Timing_residuals_no_torque.pdf")


ax2.legend(framealpha=0.9, loc=1)
fig2.savefig("img/nu_dot_no_torque.pdf")

plt.show()
# Out:
# {'epsI1': 0.0, 'beta30': 'nan', 'chi0': 10.0, 'beta75': 'nan', 'n': 1000.0, 'a0': 20.0, 'tauP': 1000.5072145190425, 'T': 5000.0, 'AnomTorque': 1.0, 'Bs': '0.0', 'upsilon': 0.0, 'omega_dot0': -0.0, 'epsA': 0.0, 'delta_omega_dot0_FP': 7.8074260553080154e-05, 'omega0': 6.28, 'epsI3': 0.001}
# {'epsI1': 0.0, 'beta30': 'nan', 'chi0': 19.98, 'beta75': 'nan', 'n': 1000.0, 'a0': 20.0, 'tauP': 1000.5072145190425, 'T': 5000.0, 'AnomTorque': 1.0, 'Bs': '0.0', 'upsilon': 0.0, 'omega_dot0': -0.0, 'epsA': 0.0, 'delta_omega_dot0_FP': 3.7864538347777891e-05, 'omega0': 6.28, 'epsI3': 0.001}
# {'epsI1': 0.0, 'beta30': 'nan', 'chi0': 80.0, 'beta75': 'nan', 'n': 1000.0, 'a0': 20.0, 'tauP': 1000.5072145190425, 'T': 5000.0, 'AnomTorque': 1.0, 'Bs': '0.0', 'upsilon': 0.0, 'omega_dot0': -0.0, 'epsA': 0.0, 'delta_omega_dot0_FP': 2.4274227718238522e-06, 'omega0': 6.28, 'epsI3': 0.001}

# %%
a0 = 2
epsI3 = 1e-3
omega0 = 2 * np.pi
epsA = 0.0
T = 5e3

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, np.degrees(theta_0), 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$", "something else"]
color_list = ["b", "r", "g", "k"]

fig1 = plt.figure(figsize=(7.3, 5.2))
ax_1 = fig1.add_subplot(111, yticklabels=[], xticklabels=[], ylabel="Timing residual")
ax_1.yaxis.labelpad = 30
ax11 = fig1.add_subplot(311)
ax12 = fig1.add_subplot(312)
ax13 = fig1.add_subplot(313)

fig2 = plt.figure(figsize=(7.3, 5.2))
ax_2 = fig2.add_subplot(111, yticklabels=[], xticklabels=[], ylabel=r"$\dot{\nu}$")
ax_2.yaxis.labelpad = 30
ax21 = fig2.add_subplot(311)
ax22 = fig2.add_subplot(312)
ax23 = fig2.add_subplot(313)

        

for chi0, label, color, ax1, ax2 in zip(chi0_list, label_list, color_list, 
                                        [ax11, ax12, ax13], 
                                        [ax21, ax22, ax23] ):
    
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                     n=10000, error=1e-16, a0=a0, cleanup=True)
    
    ax1 = Plot.timing_residual(file_name, ax=ax1, 
                                    label=label, color=color,
                                    analytic="FP")
    
    ax2 = Plot.nu_dot(file_name, ax=ax2, normalise=True,
                                    label=label, color=color)
    
   
    ax1.set_xlabel("")
    ax1.set_ylabel("")
    #ax1.set_yticklabels([])
    ax1.legend(framealpha=0.8)
    ax2.set_ylabel("")
    ax2.set_xlabel("")
    #ax2.set_yticklabels([])
    ax2.legend(framealpha=0.8)
    locators = np.diff(ax2.get_ylim())[0]/5.
    ax2.yaxis.set_major_locator(MultipleLocator(locators))
    
ax11.set_xticklabels([]) 
ax12.set_xticklabels([])
fig1.subplots_adjust(hspace=0.2)
#ax1.axhline(0.0, ls="-", color="k", lw=.5)    
#ax1.legend(framealpha=0.9, loc=1)
fig1.savefig("img/Timing_residuals_no_torque.pdf")

ax21.set_xticklabels([]) 
ax22.set_xticklabels([])
fig2.subplots_adjust(hspace=0.2)
#ax2.legend(framealpha=0.9, loc=1)
#ax22.set_xlim(1e3, 5e3)
#ax22.set_ylim()
fig2.savefig("img/nu_dot_no_torque.pdf")

plt.show()

# %%
File_Functions.PrintParameterDictionary(file_name)
# Out:
# File: ./data/chi0_80.00000_omega0_6.28e+00_epsI3_1.00e-03_n_10000_a0_2.00000_T_5.00e+03_upsilon_0.000_epsA_0.00e+00_epsI1_0.00e+00_AnomTorque_1.hdf5
# epsI1 : 0.0000e+00
# chi0 : 8.0000e+01
# n : 1.0000e+04
# a0 : 2.0000e+00
# tauP : 1.0005e+03
# T : 5.0000e+03
# AnomTorque : 1.0000e+00
# Bs : 0.0000e+00
# upsilon : 0.0000e+00
# omega_dot0 : -0.0000e+00
# epsA : 0.0000e+00
# delta_omega_dot0_FP : 2.4274e-07
# omega0 : 6.2800e+00
# epsI3 : 1.0000e-03

# %% [markdown]
# ## Pulse amplitude

# %%
epsI1=0.0
epsI3=3.0e-2
epsA=0.0
omega0=1
error=1e-12
T=250 
chi0 = 70.0
AnomTorque=True
a0=10.0
upsilon=0.0
n=10000
cleanup=False
Phi0=180
Theta0=50
sigmaPhi=0.5
sigmaTheta=0.5

Phi0 = np.radians(Phi0)
Theta0 = np.radians(Theta0)

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                     n=1000, error=1e-16, a0=a0, cleanup=True, upsilon=upsilon)
    
ax = Plot.Amplitude(file_name, Phi0, Theta0, sigmaPhi, sigmaTheta, 
                          )
plt.savefig("img/amplitude_variation.pdf")
plt.show()

# %%
epsI1=0.0
epsI3=3.0e-4
epsA=0.0
omega0=1
error=1e-12
T=4e4
chi0 = 70.0
a0=10
AnomTorque=True
upsilon=0.0
n=100000
cleanup=False,
Phi0=180
Theta0=50
sigmaPhi=0.3
sigmaTheta=0.3
eta=0.01

Phi0 = np.radians(Phi0)
Theta0 = np.radians(Theta0)

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                     n=1000, error=1e-16, a0=a0, cleanup=True, upsilon=upsilon)

ax = Plot.PulseWidth(file_name, Phi0, Theta0, sigmaPhi, sigmaTheta, 
                      eta=eta, ls="-")
plt.savefig("img/Pulse_width_modulation.pdf")
plt.show()
