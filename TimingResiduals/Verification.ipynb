# %%
import numpy as np
from matplotlib import pyplot as plt
import nsmod
import os 
import numpy as np
# %matplotlib inline

from nsmod.one_component_model_with_Euler import main
from nsmod import Plot, File_Functions, Model, Physics_Functions

# %% [markdown]
# # B1828-11

# %%
# Standard values
R = 1e6
c = 3e10
I0 = 1e45

# B1828-11 Values
tauP = 500 * 86400 # Precession period
nu0 = 2.469 
B0 = 5e12
a0 = 2
chi0 = 49.99

# Derived values
omega0 = 2 * np.pi * nu0
epsI3 = 1.0/(nu0 * tauP) 
epsA = B0**2 * R**5 / (4 * I0 * c**2)

# Simulation values
T = 3000 * 86400
n = 500000
error = 1e-10

print "True values for B1828-11"
file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=True, DryRun=True, 
                 )

File_Functions.PrintParameterDictionary(file_name)
print
# Out:
# True values for B1828-11
# BETA FUNCTION IS USED
# Bs : 4.9984e+12
# DeltaPhi_49 : 2.9290e-02
# DeltaPhi_63 : 8.7896e-01
# DeltaPhi_75 : 9.1412e-03
# EMtorqueAmplificationfactor : 9.4276e+01
# P : 4.0537e-01
# T : 2.5900e+08
# a0 : 2.0000e+00
# beta : -3.6427e-04
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : 6.1914e-16
# epsA : 6.9400e-12
# epsI1 : 0.0000e+00
# epsI3 : 9.3800e-09
# n : 5.0000e+05
# omega0 : 1.5500e+01
# omega_dot0 : -3.1717e-13
# tauA : 5.8410e+10
# tauE : 4.8870e+13
# tauP : 4.3216e+07
# tauS : 2.6989e+13
# wobble_angle : 3.4907e-02

# %% [markdown]
# ## Old pulsar TR dominated by precession

# %%
# Manual changes
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e1
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

print "Old pulsar: TR dominate by precession"
file_name = main(chi0=chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.timing_residual(file_name, ax=ax1, analytic=True)
ax1.set_title('Old pulsar with TR dominated by precession')
plt.legend()
plt.show()
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806e+14
# DeltaPhi_49 : 2.9290e-02
# DeltaPhi_63 : 8.7896e-03
# DeltaPhi_75 : 9.1412e-05
# EMtorqueAmplificationfactor : 9.4276e-01
# P : 4.0537e-02
# T : 2.2500e+04
# a0 : 2.0000e+00
# beta : -3.6427e-04
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : 6.1914e-08
# epsA : 6.9400e-09
# epsI1 : 0.0000e+00
# epsI3 : 9.3800e-06
# n : 5.0000e+05
# omega0 : 1.5500e+02
# omega_dot0 : -3.1717e-07
# tauA : 5.8410e+06
# tauE : 4.8870e+08
# tauP : 4.3216e+03
# tauS : 2.6989e+08
# wobble_angle : 3.4907e-02
# BETA FUNCTION IS USED

# %% [markdown]
# ## Yound pulsar: TR amplified by torque

# %%
# Manual changes
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e2
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

print "Old pulsar: TR dominate by precession"
file_name = main(chi0=chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.timing_residual(file_name, ax=ax1, analytic=True)
ax1.set_title('Old pulsar with TR dominated by precession')
plt.legend()
plt.show()
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806e+14
# DeltaPhi_49 : 2.9290e-02
# DeltaPhi_63 : 8.7896e-02
# DeltaPhi_75 : 9.1412e-04
# EMtorqueAmplificationfactor : 9.4276e+00
# P : 4.0537e-03
# T : 2.2500e+03
# a0 : 2.0000e+00
# beta : -3.6427e-04
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : 6.1914e-06
# epsA : 6.9400e-09
# epsI1 : 0.0000e+00
# epsI3 : 9.3800e-06
# n : 5.0000e+05
# omega0 : 1.5500e+03
# omega_dot0 : -3.1717e-04
# tauA : 5.8410e+05
# tauE : 4.8870e+06
# tauP : 4.3216e+02
# tauS : 2.6989e+06
# wobble_angle : 3.4907e-02
# BETA FUNCTION IS USED

# %% [markdown]
# ## Young pulsar with chi close to $\pi/2$
#
# Like B1828-11 in Jones 2001

# %%
# Manual changes
new_chi0 = 89.9
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e2
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

print "Old pulsar: TR dominate by precession"
file_name = main(chi0=new_chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.timing_residual(file_name, ax=ax1, analytic=True)
ax1.set_title('Old pulsar with TR dominated by precession')
plt.legend()
plt.show()
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806e+14
# DeltaPhi_49 : 6.0924e-05
# DeltaPhi_63 : 3.3060e-04
# DeltaPhi_75 : 1.6530e-03
# EMtorqueAmplificationfactor : 1.7048e+01
# P : 4.0537e-03
# T : 2.2500e+03
# a0 : 2.0000e+00
# beta : -1.2904e-06
# chi0 : 8.9900e+01
# delta_omega_dot0_FP : 1.2878e-08
# epsA : 6.9400e-09
# epsI1 : 0.0000e+00
# epsI3 : 9.3800e-06
# n : 5.0000e+05
# omega0 : 1.5500e+03
# omega_dot0 : -5.7353e-04
# tauA : 5.8410e+05
# tauE : 2.7025e+06
# tauP : 4.3216e+02
# tauS : 2.6989e+06
# wobble_angle : 3.4907e-02
# BETA FUNCTION IS USED
