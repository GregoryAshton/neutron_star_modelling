# %%
# %load_ext autoreload
# %autoreload 1

# %%
import numpy as np
from matplotlib import pyplot as plt
import nsmod
import os 
import numpy as np
# %matplotlib inline

from nsmod.one_component_model_with_Euler import main
from nsmod import Plot, File_Functions, Model, Physics_Functions

# %aimport nsmod.File_Functions
# Out:
# /usr/lib/python2.7/dist-packages/gtk-2.0/gtk/__init__.py:127: RuntimeWarning: PyOS_InputHook is not available for interactive use of PyGTK
#   set_interactive(1)

# %% [markdown]
# # B1828-11

# %%
# Standard values
R = 1e6
c = 3e10
I0 = 1e45

# B1828-11 Values
tauP = 500 * 86400 # Precession period
nu0 = 2.469 
B0 = 5e12
a0 = 2
chi0 = 49.99

# Derived values
omega0 = 2 * np.pi * nu0
epsI3 = 1.0/(nu0 * tauP) 
epsA = B0**2 * R**5 / (4 * I0 * c**2)

# Simulation values
T = 3000 * 86400
n = 500000
error = 1e-12

print "True values for B1828-11"
file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=True, DryRun=True, 
                 )

File_Functions.PrintParameterDictionary(file_name)
print
# Out:
# True values for B1828-11
# BETA FUNCTION IS USED
# Bs : 4.9983997439e+12
# DeltaPhi_49 : 2.9606271280e-02
# DeltaPhi_49_SpindownTorque : 1.2607413139e-14
# DeltaPhi_63 : 8.8817200754e-01
# DeltaPhi_75 : 9.3300910379e-03
# EMtorqueAmplificationfactor : 9.4246067924e+01
# P : 4.0536679401e-01
# T : 2.5900000000e+08
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-14
# beta : -2.0872365516e-02
# chi0 : 4.9990000000e+01
# delta_omega_dot0_FP : 6.1936106083e-16
# epsA : 6.9400000000e-12
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-09
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+01
# omega_dot0 : -3.1706802296e-13
# tauA : 5.8410200866e+10
# tauE : 4.8885409053e+13
# tauP : 4.3216076121e+07
# tauS : 2.6989177340e+13
# wobble_angle : 3.5270876541e-02

# %% [markdown]
# ## Old pulsar TR dominated by precession

# %%
# Manual changes
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e1
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

print "Old pulsar: TR dominate by precession"
file_name = main(chi0=chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.PhaseResidual(file_name, ax=ax1, analytic="49")
plt.legend(frameon=True)
plt.savefig("img/49_verification.pdf")
plt.show()

File_Functions.PropertiesTable(file_name, "49_verification")
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 2.9606271280e-02
# DeltaPhi_49_SpindownTorque : 1.2607413139e-10
# DeltaPhi_63 : 8.8817200754e-03
# DeltaPhi_75 : 9.3300910379e-05
# EMtorqueAmplificationfactor : 9.4246067924e-01
# P : 4.0536679401e-02
# T : 2.2500000000e+04
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-10
# beta : -2.0872365511e-02
# chi0 : 4.9990000000e+01
# delta_omega_dot0_FP : 6.1936106083e-08
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+02
# omega_dot0 : -3.1706802296e-07
# tauA : 5.8410200866e+06
# tauE : 4.8885409053e+08
# tauP : 4.3216076121e+03
# tauS : 2.6989177340e+08
# wobble_angle : 3.5270876541e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED

# %% [markdown]
# ## Yound pulsar: TR amplified by torque

# %%
# Manual changes
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e2
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

file_name = main(chi0=chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.PhaseResidual(file_name, ax=ax1, analytic=['49', "63"])
plt.legend()
plt.savefig("img/63_verification.pdf")
plt.show()

File_Functions.PropertiesTable(file_name, "63_verification")
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 2.9606271280e-02
# DeltaPhi_49_SpindownTorque : 1.2607413139e-09
# DeltaPhi_63 : 8.8817200754e-02
# DeltaPhi_75 : 9.3300910379e-04
# EMtorqueAmplificationfactor : 9.4246067924e+00
# P : 4.0536679401e-03
# T : 2.2500000000e+03
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-09
# beta : -2.0872365511e-02
# chi0 : 4.9990000000e+01
# delta_omega_dot0_FP : 6.1936106083e-06
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+03
# omega_dot0 : -3.1706802296e-04
# tauA : 5.8410200866e+05
# tauE : 4.8885409053e+06
# tauP : 4.3216076121e+02
# tauS : 2.6989177340e+06
# wobble_angle : 3.5270876541e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED

# %% [markdown]
# ## Young pulsar with chi close to $\pi/2$
#
# Like B1828-11 in Jones 2001

# %%
# Manual changes
new_chi0 = 89.9
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e2
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

print "Old pulsar: TR dominate by precession"
file_name = main(chi0=new_chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)


ax1 = plt.subplot(111)
ax1 = Plot.PhaseResidual(file_name, ax=ax1, analytic='75')
ax1.set_title('Old pulsar with TR dominated by precession')
plt.legend()
plt.show()
# Out:
# Old pulsar: TR dominate by precession
# WARNING: File already exists and cleanup=False
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 6.0925797908e-05
# DeltaPhi_49_SpindownTorque : 2.6214183295e-12
# DeltaPhi_63 : 3.3061355358e-04
# DeltaPhi_75 : 1.6531271964e-03
# EMtorqueAmplificationfactor : 1.7047837645e+01
# P : 4.0536679401e-03
# T : 2.2500000000e+03
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-09
# beta : -7.3931654584e-05
# chi0 : 8.9900000000e+01
# delta_omega_dot0_FP : 1.2878172703e-08
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+03
# omega_dot0 : -5.7353312417e-04
# tauA : 5.8410200866e+05
# tauE : 2.7025466092e+06
# tauP : 4.3216076121e+02
# tauS : 2.6989177340e+06
# wobble_angle : 3.4907875391e-02
# BETA FUNCTION IS USED

# %% [markdown]
# ## Variations with $\chi$ for young pulsar

# %%
# Manual changes
new_epsI3 = epsI3 * 1e3
new_epsA = epsA * 1e3
new_omega0 = omega0 * 1e2
new_tauP = 2 * np.pi/(new_epsI3 * new_omega0)
new_T = 5.2 * new_tauP

ax1 = plt.subplot(111)

for chi0 in [30.0, 55.0, 70.0]:
    file_name = main(chi0=chi0, epsI3=new_epsI3, epsA=new_epsA, omega0=new_omega0, T=new_T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

    File_Functions.PrintParameterDictionary(file_name)



    ax1 = Plot.PhaseResidual(file_name, ax=ax1, analytic=['49', "63"])
    
plt.legend()
plt.savefig("img/variation_with_chi.pdf")
plt.show()

File_Functions.PropertiesTable(file_name, "63_verification")
# Out:
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 6.1015088138e-02
# DeltaPhi_49_SpindownTorque : 2.6014719681e-09
# DeltaPhi_63 : 7.3073313132e-02
# DeltaPhi_75 : 3.7154788677e-04
# EMtorqueAmplificationfactor : 3.7624559878e+00
# P : 4.0536679401e-03
# T : 2.2500000000e+03
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-09
# beta : -1.8362868827e-02
# chi0 : 3.0000000000e+01
# delta_omega_dot0_FP : 1.2780182740e-05
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+03
# omega_dot0 : -1.2657870061e-04
# tauA : 5.8410200866e+05
# tauE : 1.2245346117e+07
# tauP : 4.3216076121e+02
# tauS : 2.6989177340e+06
# wobble_angle : 3.5227077561e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 2.4685202818e-02
# DeltaPhi_49_SpindownTorque : 1.0516840930e-09
# DeltaPhi_63 : 8.5553327688e-02
# DeltaPhi_75 : 1.0768619980e-03
# EMtorqueAmplificationfactor : 1.0888049320e+01
# P : 4.0536679401e-03
# T : 2.2500000000e+03
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-09
# beta : -1.9912469818e-02
# chi0 : 5.5000000000e+01
# delta_omega_dot0_FP : 5.1665807118e-06
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+03
# omega_dot0 : -3.6630199517e-04
# tauA : 5.8410200866e+05
# tauE : 4.2314811834e+06
# tauP : 4.3216076121e+02
# tauS : 2.6989177340e+06
# wobble_angle : 3.5254123200e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# Bs : 1.5806327847e+14
# DeltaPhi_49 : 1.2791457493e-02
# DeltaPhi_49_SpindownTorque : 5.4666893000e-10
# DeltaPhi_63 : 5.9752313727e-02
# DeltaPhi_75 : 1.4423910898e-03
# EMtorqueAmplificationfactor : 1.4675218203e+01
# P : 4.0536679401e-03
# T : 2.2500000000e+03
# a0 : 2.0000000000e+00
# alpha_spindown : 1.5019605411e-09
# beta : -1.3616661939e-02
# chi0 : 7.0000000000e+01
# delta_omega_dot0_FP : 2.6856060374e-06
# epsA : 6.9400000000e-09
# epsI1 : 0.0000000000e+00
# epsI3 : 9.3800000000e-06
# n : 5.0000000000e+05
# omega0 : 1.5500000000e+03
# omega_dot0 : -4.9371210114e-04
# tauA : 5.8410200866e+05
# tauE : 3.1394814841e+06
# tauP : 4.3216076121e+02
# tauS : 2.6989177340e+06
# wobble_angle : 3.5144240624e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
