# %% [markdown]
# # Manual switching of the torque
#
# We now investigate a single simple manual switch of the EM torque. This is for both
# components: the anomalous and spindown torque.

# %%
import numpy as np
from matplotlib import pyplot as plt
import nsmod
import os 
import numpy as np
# %matplotlib inline

from nsmod.manual_switching_torque_with_Euler import main
from nsmod import Plot, File_Functions, Model, Physics_Functions
# Out:
# /usr/lib/python2.7/dist-packages/gtk-2.0/gtk/__init__.py:127: RuntimeWarning: PyOS_InputHook is not available for interactive use of PyGTK
#   set_interactive(1)

# %%
# Parameters
chi0 = 49.99
epsI3 = 1e-5
epsA = 2e-6
omega0 = 1.5e1
tauP = 2 * np.pi/(epsI3 * omega0)
T = 10.2 * tauP

upsilon = 0.0
SwitchTime = T/2.

# Set it to minimal precession
beta = np.degrees(Physics_Functions.Beta_Function(epsI3, epsA, chi0))
a0 = beta 

# Simulation parameters
n = 100000
error = 1e-12

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 SwitchTime=SwitchTime, upsilon=upsilon)

File_Functions.PrintParameterDictionary(file_name)

ax1 = Plot.timing_residual(file_name, analytic=False)
leg = plt.legend()
plt.show()
# Out:
# BETA FUNCTION IS USED
# Assuming chi has been given in degrees rather than radians
# BETA FUNCTION IS USED
# AnomTorque : 1.0000e+00
# Bs : 2.6833e+15
# DeltaPhi_49 : -7.8937e-02
# DeltaPhi_63 : -7.1295e-01
# DeltaPhi_75 : 1.9983e-02
# DeltaPhi_TS : -0.0000e+00
# EMtorqueAmplificationfactor : 2.8374e+01
# P : 4.1888e-01
# SwitchTime : 2.1400e+05
# T : 4.2700e+05
# a0 : -5.3900e+00
# beta : -9.4050e-02
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : -1.7761e-09
# epsA : 2.0000e-06
# epsI1 : 0.0000e+00
# epsI3 : 1.0000e-05
# n : 1.0000e+05
# omega0 : 1.5000e+01
# omega_dot0 : -1.0161e-07
# tauA : 2.0944e+05
# tauE : 1.4763e+08
# tauP : 4.1888e+04
# tauS : 1.0000e+08
# upsilon : 0.0000e+00
# wobble_angle : -9.4073e-02
# BETA FUNCTION IS USED
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# # Young pulsar switching

# %%
# Parameters
upsilon = 0.005

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 SwitchTime=SwitchTime, upsilon=upsilon)

File_Functions.PrintParameterDictionary(file_name)


analytic=False
fig1, ax1 = plt.subplots()
ax1 = Plot.timing_residual(file_name, ax=ax1, analytic=False)
leg = plt.legend()


fig2, ax2 = plt.subplots(nrows=1)
ax2 = Plot.timing_residual(file_name, ax=ax2, analytic=False, 
                           tstart=0, tend=SwitchTime)
ax2 = Plot.timing_residual(file_name, ax=ax2, analytic=False, 
                           tstart=SwitchTime, tend=None)


fig, ax3 = plt.subplots()
ax3 = Plot.nu_dot(file_name, divisor=100, ax=ax3)
plt.show()
# Out:
# BETA FUNCTION IS USED
# AnomTorque : 1.0000e+00
# Bs : 2.6833e+15
# DeltaPhi_49 : -7.8937e-02
# DeltaPhi_63 : -7.1295e-01
# DeltaPhi_75 : 1.9983e-02
# DeltaPhi_TS : -5.7894e+00
# EMtorqueAmplificationfactor : 2.8374e+01
# P : 4.1888e-01
# SwitchTime : 2.1400e+05
# T : 4.2700e+05
# a0 : -5.3900e+00
# beta : -9.4050e-02
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : -1.7761e-09
# epsA : 2.0000e-06
# epsI1 : 0.0000e+00
# epsI3 : 1.0000e-05
# n : 1.0000e+05
# omega0 : 1.5000e+01
# omega_dot0 : -1.0161e-07
# tauA : 2.0944e+05
# tauE : 1.4763e+08
# tauP : 4.1888e+04
# tauS : 1.0000e+08
# upsilon : 5.0000e-03
# wobble_angle : -9.4073e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED

# %% [markdown]
# ## Precession dominated TR

# %%
# Parameters
epsI3 = 1e-5
epsA = 1e-6
upsilon = 0.005
omega0 = 1.e0

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=True, DryRun=False, 
                 SwitchTime=SwitchTime, upsilon=upsilon)

File_Functions.PrintParameterDictionary(file_name)


analytic=False
fig1, ax1 = plt.subplots()
ax1 = Plot.timing_residual(file_name, ax=ax1, analytic=False)
leg = plt.legend()


fig2, ax2 = plt.subplots(nrows=1)
ax2 = Plot.timing_residual(file_name, ax=ax2, analytic=False, 
                           tstart=0, tend=SwitchTime)
ax2 = Plot.timing_residual(file_name, ax=ax2, analytic=False, 
                           tstart=SwitchTime, tend=None)


fig, ax3 = plt.subplots()
ax3 = Plot.nu_dot(file_name, divisor=100, ax=ax3)
plt.show()
# Out:
# BETA FUNCTION IS USED
# AnomTorque : 1.0000e+00
# Bs : 1.8974e+15
# DeltaPhi_49 : -7.8937e-02
# DeltaPhi_63 : -2.3765e-02
# DeltaPhi_75 : 6.6608e-04
# DeltaPhi_TS : -8.5769e-04
# EMtorqueAmplificationfactor : 9.4582e-01
# P : 6.2832e+00
# SwitchTime : 2.1400e+05
# T : 4.2700e+05
# a0 : -5.3900e+00
# beta : -4.8250e-02
# chi0 : 5.0000e+01
# delta_omega_dot0_FP : -7.8937e-12
# epsA : 1.0000e-06
# epsI1 : 0.0000e+00
# epsI3 : 1.0000e-05
# n : 1.0000e+05
# omega0 : 1.0000e+00
# omega_dot0 : -1.5053e-11
# tauA : 6.2832e+06
# tauE : 6.6431e+10
# tauP : 6.2832e+05
# tauS : 4.5000e+10
# upsilon : 5.0000e-03
# wobble_angle : -9.4073e-02
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
