# %%
# %matplotlib inline
from nsmod.switching_torque_with_Euler import main
from nsmod import Plot, File_Functions
import matplotlib.pyplot as plt

file_name = main(epsI1=0.0, epsI3=3.0e-3, epsA=5.0e-4 , omega0=10,
                error=1e-12, T=3.0e3 , chi0 = 70.0, AnomTorque=True ,
                a0=20.0, upsilon=0.0, n=20000, cleanup=False)

fig = Plot.Spherical_Plot(file_name)
plt.show()

fig = Plot.Euler_Angles(file_name)

fig = Plot.timing_residual(file_name, order=3)

fig = Plot.nu_dot(file_name)

plt.show()

File_Functions.Clean_Data(".", ask_user=False)
