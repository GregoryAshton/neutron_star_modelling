# %%
import numpy as np
from matplotlib import pyplot as plt
import nsmod
import os 
# %matplotlib inline

from nsmod.one_component_model_with_Euler import main
from nsmod import Plot, File_Functions, Physics_Functions

# %% [markdown]
# ## Variations due to free precession

# %%
epsI3 = 5e-6
omega0 = 1e2
epsA = 0.0
chi0 = 60.0
tauP = 2 * np.pi/(epsI3 * omega0)
T = 5.2 * tauP
a0 = 3.0

n = 50000
error = 1e-13

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)

Plot.nu_dot(file_name)
plt.show()
# Out:
# WARNING: File already exists and cleanup=False
# DeltaPhi_49 : 3.0229989404e-02
# P : 6.2831853072e-02
# T : 6.5300000000e+04
# a0 : 3.0000000000e+00
# beta : 0.0000000000e+00
# chi0 : 6.0000000000e+01
# delta_omega_dot0_FP : 7.5574973510e-09
# epsA : 0.0000000000e+00
# epsI1 : 0.0000000000e+00
# epsI3 : 5.0000000000e-06
# n : 5.0000000000e+04
# omega0 : 1.0000000000e+02
# tauP : 1.2566370614e+04
# wobble_angle : 5.2359877560e-02
# wobble_angle_spindown : 0.0000000000e+00

# %% [markdown]
# ## With the torque

# %%
epsI3 = 5e-6
omega0 = 1e2
epsA = 1e-8
chi0 = 60.0
tauP = 2 * np.pi/(epsI3 * omega0)
T = 5.2 * tauP
a0 = 3.0

n = 50000
error = 1e-13

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=n, error=error, a0=a0, cleanup=False, DryRun=False, 
                 )

File_Functions.PrintParameterDictionary(file_name)

Plot.nu_dot(file_name)
plt.show()
# Out:
# BETA FUNCTION IS USED
# Bs : 1.8973665961e+14
# DeltaPhi_49 : 3.0745612147e-02
# DeltaPhi_49_SpindownTorque : 1.6122741629e-05
# DeltaPhi_63 : 3.8445314863e-02
# DeltaPhi_75 : 8.8651855471e-04
# EMtorqueAmplificationfactor : 3.9283497808e+00
# P : 6.2831853072e-02
# T : 6.5300000000e+04
# a0 : 3.0000000000e+00
# beta : -4.9569981087e-02
# chi0 : 6.0000000000e+01
# delta_omega_dot0_FP : 7.5574973510e-09
# epsA : 1.0000000000e-08
# epsI1 : 0.0000000000e+00
# epsI3 : 5.0000000000e-06
# n : 5.0000000000e+04
# omega0 : 1.0000000000e+02
# omega_dot0 : -1.5630407145e-07
# tauA : 6.2831853072e+06
# tauE : 6.3977859995e+08
# tauP : 1.2566370614e+04
# tauS : 4.5000000000e+08
# wobble_angle : 5.3252962348e-02
# wobble_angle_spindown : 2.7925407658e-05
# BETA FUNCTION IS USED
